# %% [markdown]
# # NHL Data EDA
#
# Exploratory data analysis for the NHL point prediction project.

# %%
# TODO: Load processed data and explore
# import pandas as pd
# df = pd.read_parquet("data/processed/...")
